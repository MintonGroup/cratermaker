# %%
import cratermaker

# %%
mars = cratermaker.Target(name="Mars") 
scale_mars = cratermaker.Scale(mars)
# Out:
# here 1

# %%
cat= mars.catalogue
print(cat)

print(cat['Mercury']['gravity'])

keys = cat.keys()
gravities = {}
for key in keys:
    gravities[key]=cat[key]['gravity']
print(gravities)
gravities2 = {}
for key in cat:
    gravities2[key]=cat[key]['gravity']
print(gravities2)

print(dict(map(lambda x: [x,cat[x]['gravity']], cat)))
# Out:
# {'Mercury': {'radius': 2440000.0, 'gravity': 3.6971070499999996, 'material_name': 'Soft Rock', 'transition_scale_type': 'silicate'}, 'Venus': {'radius': 6051840.0, 'gravity': 8.87501825, 'material_name': 'Hard Rock', 'transition_scale_type': 'silicate'}, 'Earth': {'radius': 6371010.0, 'gravity': 9.80665, 'material_name': 'Wet Soil', 'transition_scale_type': 'silicate'}, 'Moon': {'radius': 1737530.0, 'gravity': 1.6249619049999997, 'material_name': 'Soft Rock', 'transition_scale_type': 'silicate'}, 'Mars': {'radius': 3389920.0, 'gravity': 3.7167203499999997, 'material_name': 'Soft Rock', 'transition_scale_type': 'silicate'}, 'Ceres': {'radius': 469700.0, 'gravity': 0.28439285, 'material_name': 'Ice', 'transition_scale_type': 'ice'}, 'Vesta': {'radius': 262700.0, 'gravity': 0.24516625, 'material_name': 'Soft Rock', 'transition_scale_type': 'silicate'}}
# 3.6971070499999996
# ...

# %%
d= mars.diameter
print(d)
# Out:
# 6779840.0

# %%
v_esc= mars.escape_velocity
print(v_esc)
# Out:
# 5019.837576828955

# %%
material= mars.material_name
print(material)
# Out:
# Soft Rock

# %%
name= mars.name
print(name)
# Out:
# Mars

# %%
radius= mars.radius
print(radius)
# Out:
# 3389920.0

# %%
trans = mars.transition_scale_type 
print(trans)
# Out:
# silicate

# %%
material= cratermaker.Material(name='Water')

# %%
name= material.name
print(name)
# Out:
# Water

# %%
cat2= material.catalogue
print(cat2)
# Out:
# {'Water': {'K1': 2.3, 'mu': 0.55, 'Ybar': 0.0, 'density': 1000.0}, 'Sand': {'K1': 0.24, 'mu': 0.41, 'Ybar': 0.0, 'density': 1750.0}, 'Dry Soil': {'K1': 0.24, 'mu': 0.41, 'Ybar': 180000.0, 'density': 1500.0}, 'Wet Soil': {'K1': 0.2, 'mu': 0.55, 'Ybar': 1140000.0, 'density': 2000.0}, 'Soft Rock': {'K1': 0.2, 'mu': 0.55, 'Ybar': 7600000.0, 'density': 2250.0}, 'Hard Rock': {'K1': 0.2, 'mu': 0.55, 'Ybar': 18000000.0, 'density': 2500.0}, 'Ice': {'K1': 15.625, 'mu': 0.48, 'Ybar': 0.0, 'density': 900.0}}
